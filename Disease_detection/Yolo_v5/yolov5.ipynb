# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="iyLsqEim9nAoDa24N72g")
project = rf.workspace("industrial-engineer").project("cotton-disease-zrbov")
version = project.version(21)
dataset = version.download("yolov5")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.6/88.6 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 35.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 57.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 85.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 27.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 29.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 14.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 18.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 30.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import yaml
from pathlib import Path

# 1. where your dataset actually is
DATASET = Path("/kaggle/working/Cotton-Disease-21")   # adjust if different
train_imgs = DATASET / "train" / "images"
val_imgs   = DATASET / "valid" / "images"             # or "val"

assert train_imgs.exists(), train_imgs
assert val_imgs.exists(),   val_imgs

# 2. build correct yaml
yaml_correct = {
    "path": str(DATASET),      # root
    "train": "train/images",   # relative to root
    "val":   "valid/images",   # or "val/images"
    "nc": 1,
    "names": ["cotton_disease"]
}

yaml_file = DATASET / "cotton_fixed.yaml"
yaml_file.write_text(yaml.dump(yaml_correct))
print("✅ saved clean yaml ->", yaml_file)
# Out:
# ✅ saved clean yaml -> /kaggle/working/Cotton-Disease-21/cotton_fixed.yaml

# %%
from ultralytics import YOLO

# COCO-pretrained YOLOv5n
model = YOLO("yolov5nu.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...

# %%
# Optional: print layer summary
model.info()

results = model.train(
    data=str(yaml_file),
    epochs=100,             # Increase training epochs
    batch=8,
    imgsz=1024,              # Higher resolution
    workers=2,
    lr0=0.01,               # Initial learning rate
    lrf=0.01,               # Final learning rate fraction (end of cosine schedule)
    momentum=0.937,         # Momentum for optimizer
    weight_decay=0.0005,    # Helps regularization
    warmup_epochs=3,        # Warmup for stable initial convergence
    augment=True,
    device=[0,1],
    patience=10,  # controls both early stopping & LR scheduler patience
    optimizer='AdamW',
    close_mosaic=10,  # Disable heavy mosaic after 10 epochs (optional)
    # degrees=5,  # Rotation augmentation
    # translate=0.03,  # Shift augmentation
    # scale=0.1,  # Zoom augmentation
    # shear=2,  # Shear augmentation
    # perspective=0.0003,  # Perspective warping
    flipud=0.00,  # Vertical flip probability
    hsv_h=0.01,  # Hue augmentation
    # hsv_s=0.2,  # Saturation augmentation
    # #hsv_v=0.2  # Brightness augmentation
)
# Out:
# YOLOv5n summary: 153 layers, 2,654,816 parameters, 0 gradients, 7.8 GFLOPs
# Ultralytics 8.3.195 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#                                                         CUDA:1 (Tesla T4, 15095MiB)
# ...

# %%
# ==========================================
# 1. CLONE YOLOv5 (only once)
# ==========================================
YOLOV5_DIR = ROOT / "yolov5"
if not YOLOV5_DIR.exists():
    subprocess.run("git clone https://github.com/ultralytics/yolov5.git", shell=True, cwd=ROOT)
    subprocess.run("pip install -qr yolov5/requirements.txt", shell=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_19/1172271985.py in <cell line: 0>()
#       2 # 1. CLONE YOLOv5 (only once)
#       3 # ==========================================
# ----> 4 YOLOV5_DIR = ROOT / "yolov5"
#       5 if not YOLOV5_DIR.exists():
#       6     subprocess.run("git clone https://github.com/ultralytics/yolov5.git", shell=True, cwd=ROOT)
#
# NameError: name 'ROOT' is not defined

# %%
# ==========================================
# 2. TRAIN YOLOv5n
# ==========================================
IMG = 640
EPOCHS = 100
BATCH = 32 if torch.cuda.is_available() else 8
DEVICE = [0,1] if torch.cuda.is_available() else "cpu"

cmd = f"""python {YOLOV5_DIR}/train.py \
--img {IMG} \
--batch {BATCH} \
--epochs {EPOCHS} \
--data {YAML_PATH} \
--weights yolov5n.pt \
--project {ROOT}/yolov5_train \
--name cotton_v5n \
--cache ram \
--device {DEVICE} \
--exist-ok"""
subprocess.run(cmd, shell=True)
